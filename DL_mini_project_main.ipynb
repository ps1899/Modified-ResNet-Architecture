# %%
# !pip install torchsummary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1

# %% [markdown]
# # Importing all the necessary modules

# %%
import torchvision
import torch.utils.data as data
import torchvision.transforms as transforms
import torch
import numpy as np
import copy
from torchsummary import summary
from torch.optim import lr_scheduler
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import time
import matplotlib.pyplot as plt
import pandas as pd

# Using SEED to generate random number

SEED = 1234

np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Loading CIFAR-10 Dataset

# %%
# Train transformations
# Image Normalization means based on CIFAR-10 Images

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# Test transformations

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# %%
# Training and Validation Loader
training_dataset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=train_transform)

# Validation Data ratio from Training data
valid_ratio = 0.8

# Number of training samples
num_training = int(len(training_dataset) * valid_ratio)

# Number of test samples
num_validations = len(training_dataset) - num_training

# Dividing train and validation based on number of samples
training_data, validation_data = data.random_split(training_dataset, 
                                           [num_training, num_validations])

# Train Data Loader
trainloader = torch.utils.data.DataLoader(
    training_data, batch_size = 32, shuffle = True, num_workers = 2)

# Applying test transform on validation data after a deepcopy
validation_data = copy.deepcopy(validation_data)
validation_data.dataset.transform = test_transform

# Validation Data Loader
validloader = torch.utils.data.DataLoader(
    validation_data, batch_size=128, shuffle=False, num_workers=2)

#Test Loader
test_dataset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=100, shuffle=False, num_workers=2)


#Datalaoders
dataloaders = {'train': trainloader,  'valid': validloader, 'test': testloader}
dataset_sizes = {'train': len(trainloader.dataset), 'valid': len(validloader.dataset), 'test': len(testloader.dataset)}
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# CIFAR-10 dataset comprising class labels
classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# Defining the Basic module
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=True)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=True)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=True),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# Defining the Bottleneck module
class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size = 1, bias = True)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size = 3,
                               stride = stride, padding = 1, bias = True)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size = 1, bias = True)
        self.bn3 = nn.BatchNorm2d(self.expansion * planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes,
                          kernel_size = 1, stride = stride, bias = True),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# Defining the modified ResNet module for skip connections
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10, dropout=0.6):
        super(ResNet, self).__init__()
        self.in_planes = 64
        
        # Conv layer with size 64, channel 3, kernel size 3, stride 1, padding 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size = 3,
                               stride = 1, padding = 1, bias = True)
        # Applying batch normalization
        self.bn1 = nn.BatchNorm2d(64)
        # Using make_layer function to build size 64 blocks with stride 1
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride = 1)
        # Using make_layer function to build size 128 blocks with stride 2
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride = 2)
        # Using make_layer function to build size 256 blocks with stride 2
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride = 2)
        # Using make_layer function to build size 512 blocks with stride 2
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride = 2)
        # Adding dropout 
        self.dropout = nn.Dropout(dropout)
        # Linear fully connected layer 
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    # Defining function to make convolution layer using different parameters
    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)
    
    # Feed Forward function with layout
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.dropout(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
# Defining the layer configuration
config = [2, 1, 1, 1]

# Making model 
model = ResNet(BasicBlock, config)

# Printing total training parameters
print("Number of trainable parameters:", sum(p.numel() for p in model.parameters()))
# Out:
# Number of trainable parameters: 4980234

# %%
# Function to initialize parameters
def initialize_parameters(m):
    if isinstance(m, nn.Conv2d):
        nn.init.kaiming_normal_(m.weight.data, nonlinearity = 'relu')
        nn.init.constant_(m.bias.data, 0)
    elif isinstance(m, nn.Linear):
        nn.init.xavier_normal_(m.weight.data, gain = nn.init.calculate_gain('relu'))
        nn.init.constant_(m.bias.data, 0)

# Applying initialized parameters to the model        
model.apply(initialize_parameters)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (dropout): Dropout(p=0.6, inplace=False)
#   (linear): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
# Selecting CPU or CUDA
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model = model.to(device)

# Criterion used for the model
criterion = nn.CrossEntropyLoss(reduction='sum')

# Number of Epochs
EPOCH = 300

# Learning rate
lr = 0.001

# Weight decay
weightDecay = 0.0001

# Different types of optimizer
# optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weightDecay)
# optimizer = optim.RMSprop(model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)
# optimizer = optim.Adadelta(model.parameters(), lr=lr, weight_decay=weightDecay)
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=weightDecay)

# Different types of scheduler
# scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.5)
# scheduler = lr_scheduler.ExponentialLR(optimizer, gamma = 0.9)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor = 0.5, patience=5, cooldown=2)
# scheduler = lr_scheduler.CosineAnnealingLR(optimizer, eta_min = lr/50.0, T_max=100)

# %% [markdown]
# # Training the model

# %%
# Defining function to train the model
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    start = time.time()

    best_accuracy = 0.0
    training_loss = []
    validation_loss = []
    training_accuracy = []
    validation_accuracy = []
    
    # Iterating over total number of epochs
    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode
                
            
            # Initializing statistics 
            running_loss = 0.0
            running_corrects = 0

            # Iterate over data
            for inputs, labels in dataloaders[phase]:
                # Transferring inputs and labels CPU to GPU for training
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Zero the parameter gradients
                optimizer.zero_grad()

                # Track history if current phase is in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # Backward + Optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # Statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                
            if phase == 'train':
                scheduler.step(running_loss)
            
            # Calculation per epoch loss and accuracy
            loss_per_epoch = running_loss / dataset_sizes[phase]
            accuracy_per_epoch = running_corrects.double() / dataset_sizes[phase]
            
            if phase == 'valid':
                validation_loss.append(loss_per_epoch)
                validation_accuracy.append(accuracy_per_epoch)
            else:
                training_loss.append(loss_per_epoch)
                training_accuracy.append(accuracy_per_epoch)
            
            print(f'{phase} Loss: {loss_per_epoch:.4f} Accuracy: {accuracy_per_epoch:.4f}')

            # Deep copy the model
            if phase == 'valid' and accuracy_per_epoch > best_accuracy:
                best_accuracy = accuracy_per_epoch
                best_model_wts = copy.deepcopy(model.state_dict())   

    time_elapsed = time.time() - start
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Accuracy: {best_accuracy:4f}')


    # Load the best model weights
    model.load_state_dict(best_model_wts)
    return model, training_loss, validation_loss, training_accuracy, validation_accuracy

# %%
model, training_loss, validation_loss, training_accuracy, validation_accuracy = train_model(model, criterion, optimizer, scheduler, EPOCH)
# Out:
# Epoch 0/299
# ----------
# train Loss: 52.8541 Accuracy: 0.4030
# valid Loss: 183.6120 Accuracy: 0.5041
# Epoch 1/299
# ----------
# train Loss: 37.4380 Accuracy: 0.5797
# valid Loss: 130.5907 Accuracy: 0.6412
# Epoch 2/299
# ----------
# train Loss: 30.5972 Accuracy: 0.6603
# valid Loss: 108.8548 Accuracy: 0.7055
# Epoch 3/299
# ----------
# train Loss: 26.0691 Accuracy: 0.7144
# valid Loss: 96.6784 Accuracy: 0.7528
# Epoch 4/299
# ----------
# train Loss: 22.7926 Accuracy: 0.7490
# valid Loss: 88.7677 Accuracy: 0.7729
# Epoch 5/299
# ----------
# train Loss: 20.4521 Accuracy: 0.7763
# valid Loss: 76.8354 Accuracy: 0.7998
# Epoch 6/299
# ----------
# train Loss: 18.6067 Accuracy: 0.7977
# valid Loss: 72.2227 Accuracy: 0.8099
# Epoch 7/299
# ----------
# train Loss: 17.2352 Accuracy: 0.8121
# valid Loss: 66.8764 Accuracy: 0.8251
# Epoch 8/299
# ----------
# train Loss: 15.9832 Accuracy: 0.8251
# valid Loss: 66.2056 Accuracy: 0.8298
# Epoch 9/299
# ----------
# train Loss: 14.8341 Accuracy: 0.8401
# valid Loss: 63.8814 Accuracy: 0.8382
# Epoch 10/299
# ----------
# train Loss: 13.9549 Accuracy: 0.8472
# valid Loss: 61.2481 Accuracy: 0.8425
# Epoch 11/299
# ----------
# train Loss: 13.3240 Accuracy: 0.8547
# valid Loss: 56.0266 Accuracy: 0.8548
# Epoch 12/299
# ----------
# train Loss: 12.5858 Accuracy: 0.8631
# valid Loss: 60.6268 Accuracy: 0.8458
# Epoch 13/299
# ----------
# train Loss: 11.8838 Accuracy: 0.8722
# valid Loss: 58.0082 Accuracy: 0.8497
# Epoch 14/299
# ----------
# train Loss: 11.4417 Accuracy: 0.8758
# valid Loss: 51.6599 Accuracy: 0.8673
# Epoch 15/299
# ----------
# train Loss: 10.7892 Accuracy: 0.8816
# valid Loss: 53.3247 Accuracy: 0.8660
# Epoch 16/299
# ----------
# train Loss: 10.0512 Accuracy: 0.8911
# valid Loss: 54.4919 Accuracy: 0.8656
# Epoch 17/299
# ----------
# train Loss: 9.7756 Accuracy: 0.8939
# valid Loss: 48.9943 Accuracy: 0.8773
# Epoch 18/299
# ----------
# train Loss: 9.3527 Accuracy: 0.8966
# valid Loss: 53.6271 Accuracy: 0.8681
# Epoch 19/299
# ----------
# train Loss: 8.9832 Accuracy: 0.9004
# valid Loss: 47.7193 Accuracy: 0.8789
# Epoch 20/299
# ----------
# train Loss: 8.5241 Accuracy: 0.9092
# valid Loss: 47.3245 Accuracy: 0.8812
# Epoch 21/299
# ----------
# train Loss: 8.1149 Accuracy: 0.9108
# valid Loss: 53.8001 Accuracy: 0.8712
# Epoch 22/299
# ----------
# train Loss: 7.7708 Accuracy: 0.9152
# valid Loss: 56.7246 Accuracy: 0.8623
# Epoch 23/299
# ----------
# train Loss: 7.5893 Accuracy: 0.9168
# valid Loss: 47.0177 Accuracy: 0.8833
# Epoch 24/299
# ----------
# train Loss: 7.1088 Accuracy: 0.9209
# valid Loss: 53.6711 Accuracy: 0.8755
# Epoch 25/299
# ----------
# train Loss: 6.8749 Accuracy: 0.9250
# valid Loss: 50.1114 Accuracy: 0.8829
# Epoch 26/299
# ----------
# train Loss: 6.5710 Accuracy: 0.9268
# valid Loss: 47.7078 Accuracy: 0.8917
# Epoch 27/299
# ----------
# train Loss: 6.3347 Accuracy: 0.9309
# valid Loss: 47.6741 Accuracy: 0.8898
# Epoch 28/299
# ----------
# train Loss: 6.0321 Accuracy: 0.9333
# valid Loss: 48.5658 Accuracy: 0.8936
# Epoch 29/299
# ----------
# train Loss: 5.7917 Accuracy: 0.9361
# valid Loss: 47.1854 Accuracy: 0.8933
# Epoch 30/299
# ----------
# train Loss: 5.6455 Accuracy: 0.9381
# valid Loss: 48.5826 Accuracy: 0.8877
# Epoch 31/299
# ----------
# train Loss: 5.4099 Accuracy: 0.9404
# valid Loss: 47.0970 Accuracy: 0.8947
# Epoch 32/299
# ----------
# train Loss: 5.0871 Accuracy: 0.9434
# valid Loss: 50.4911 Accuracy: 0.8899
# Epoch 33/299
# ----------
# train Loss: 4.9449 Accuracy: 0.9457
# valid Loss: 55.5561 Accuracy: 0.8796
# Epoch 34/299
# ----------
# train Loss: 4.8024 Accuracy: 0.9467
# valid Loss: 46.2370 Accuracy: 0.8957
# Epoch 35/299
# ----------
# train Loss: 4.4740 Accuracy: 0.9505
# valid Loss: 49.3542 Accuracy: 0.8905
# Epoch 36/299
# ----------
# train Loss: 4.4585 Accuracy: 0.9511
# valid Loss: 50.2156 Accuracy: 0.8904
# Epoch 37/299
# ----------
# train Loss: 4.2660 Accuracy: 0.9535
# valid Loss: 49.9057 Accuracy: 0.8926
# Epoch 38/299
# ----------
# train Loss: 4.0356 Accuracy: 0.9566
# valid Loss: 48.2188 Accuracy: 0.9018
# Epoch 39/299
# ----------
# train Loss: 4.0323 Accuracy: 0.9552
# valid Loss: 46.2682 Accuracy: 0.8978
# Epoch 40/299
# ----------
# train Loss: 3.7490 Accuracy: 0.9591
# valid Loss: 46.4590 Accuracy: 0.9038
# Epoch 41/299
# ----------
# train Loss: 3.6073 Accuracy: 0.9604
# valid Loss: 46.2454 Accuracy: 0.9001
# Epoch 42/299
# ----------
# train Loss: 3.4867 Accuracy: 0.9615
# valid Loss: 49.5742 Accuracy: 0.8962
# Epoch 43/299
# ----------
# train Loss: 3.4156 Accuracy: 0.9616
# valid Loss: 45.8288 Accuracy: 0.9038
# Epoch 44/299
# ----------
# train Loss: 3.2701 Accuracy: 0.9645
# valid Loss: 47.6621 Accuracy: 0.9025
# Epoch 45/299
# ----------
# train Loss: 3.2661 Accuracy: 0.9637
# valid Loss: 48.9033 Accuracy: 0.9002
# Epoch 46/299
# ----------
# train Loss: 3.1246 Accuracy: 0.9659
# valid Loss: 48.9590 Accuracy: 0.9004
# Epoch 47/299
# ----------
# train Loss: 2.8862 Accuracy: 0.9681
# valid Loss: 48.5487 Accuracy: 0.9049
# Epoch 48/299
# ----------
# train Loss: 2.8985 Accuracy: 0.9681
# valid Loss: 47.8676 Accuracy: 0.9035
# Epoch 49/299
# ----------
# train Loss: 2.8444 Accuracy: 0.9688
# valid Loss: 56.8346 Accuracy: 0.8911
# Epoch 50/299
# ----------
# train Loss: 2.6439 Accuracy: 0.9724
# valid Loss: 50.3775 Accuracy: 0.9006
# Epoch 51/299
# ----------
# train Loss: 2.6775 Accuracy: 0.9695
# valid Loss: 52.1402 Accuracy: 0.8998
# Epoch 52/299
# ----------
# train Loss: 2.5983 Accuracy: 0.9715
# valid Loss: 49.2391 Accuracy: 0.9058
# Epoch 53/299
# ----------
# train Loss: 2.4292 Accuracy: 0.9735
# valid Loss: 52.1953 Accuracy: 0.8999
# Epoch 54/299
# ----------
# train Loss: 2.3069 Accuracy: 0.9746
# valid Loss: 53.6860 Accuracy: 0.8977
# Epoch 55/299
# ----------
# train Loss: 2.3868 Accuracy: 0.9745
# valid Loss: 56.1291 Accuracy: 0.8952
# Epoch 56/299
# ----------
# train Loss: 2.2246 Accuracy: 0.9758
# valid Loss: 51.0127 Accuracy: 0.9041
# Epoch 57/299
# ----------
# train Loss: 2.1153 Accuracy: 0.9765
# valid Loss: 52.5102 Accuracy: 0.9051
# Epoch 58/299
# ----------
# train Loss: 2.0281 Accuracy: 0.9780
# valid Loss: 52.9199 Accuracy: 0.9050
# Epoch 59/299
# ----------
# train Loss: 2.0516 Accuracy: 0.9778
# valid Loss: 53.4258 Accuracy: 0.8999
# Epoch 60/299
# ----------
# train Loss: 1.9430 Accuracy: 0.9781
# valid Loss: 54.8929 Accuracy: 0.9023
# Epoch 61/299
# ----------
# train Loss: 1.8813 Accuracy: 0.9794
# valid Loss: 55.2582 Accuracy: 0.9036
# Epoch 62/299
# ----------
# train Loss: 2.0072 Accuracy: 0.9781
# valid Loss: 51.9817 Accuracy: 0.9047
# Epoch 63/299
# ----------
# train Loss: 1.8493 Accuracy: 0.9805
# valid Loss: 56.4145 Accuracy: 0.9012
# Epoch 64/299
# ----------
# train Loss: 1.7832 Accuracy: 0.9803
# valid Loss: 54.1941 Accuracy: 0.9044
# Epoch 65/299
# ----------
# train Loss: 1.7129 Accuracy: 0.9805
# valid Loss: 52.6480 Accuracy: 0.9045
# Epoch 66/299
# ----------
# train Loss: 1.6666 Accuracy: 0.9819
# valid Loss: 52.9884 Accuracy: 0.9053
# Epoch 67/299
# ----------
# train Loss: 1.6472 Accuracy: 0.9827
# valid Loss: 53.3635 Accuracy: 0.9058
# Epoch 68/299
# ----------
# train Loss: 1.5443 Accuracy: 0.9827
# valid Loss: 51.2796 Accuracy: 0.9093
# Epoch 69/299
# ----------
# train Loss: 1.6807 Accuracy: 0.9820
# valid Loss: 53.7401 Accuracy: 0.9042
# Epoch 70/299
# ----------
# train Loss: 1.6816 Accuracy: 0.9813
# valid Loss: 50.7557 Accuracy: 0.9067
# Epoch 71/299
# ----------
# train Loss: 1.4742 Accuracy: 0.9841
# valid Loss: 56.3680 Accuracy: 0.9061
# Epoch 72/299
# ----------
# train Loss: 1.3903 Accuracy: 0.9849
# valid Loss: 52.1499 Accuracy: 0.9128
# Epoch 73/299
# ----------
# train Loss: 1.4205 Accuracy: 0.9848
# valid Loss: 55.7498 Accuracy: 0.9034
# Epoch 74/299
# ----------
# train Loss: 1.4591 Accuracy: 0.9842
# valid Loss: 56.2594 Accuracy: 0.9051
# Epoch 75/299
# ----------
# train Loss: 1.4415 Accuracy: 0.9845
# valid Loss: 53.6271 Accuracy: 0.9084
# Epoch 76/299
# ----------
# train Loss: 1.2401 Accuracy: 0.9873
# valid Loss: 54.8947 Accuracy: 0.9116
# Epoch 77/299
# ----------
# train Loss: 1.2020 Accuracy: 0.9872
# valid Loss: 54.8366 Accuracy: 0.9089
# Epoch 78/299
# ----------
# train Loss: 1.3614 Accuracy: 0.9848
# valid Loss: 56.1936 Accuracy: 0.9100
# Epoch 79/299
# ----------
# train Loss: 1.2438 Accuracy: 0.9866
# valid Loss: 53.3080 Accuracy: 0.9148
# Epoch 80/299
# ----------
# train Loss: 1.2767 Accuracy: 0.9867
# valid Loss: 53.6835 Accuracy: 0.9101
# Epoch 81/299
# ----------
# train Loss: 1.2289 Accuracy: 0.9868
# valid Loss: 57.0854 Accuracy: 0.9044
# Epoch 82/299
# ----------
# train Loss: 1.2486 Accuracy: 0.9867
# valid Loss: 58.6877 Accuracy: 0.9070
# Epoch 83/299
# ----------
# train Loss: 1.2576 Accuracy: 0.9864
# valid Loss: 59.6422 Accuracy: 0.9034
# Epoch 84/299
# ----------
# train Loss: 0.7184 Accuracy: 0.9928
# valid Loss: 51.0552 Accuracy: 0.9169
# Epoch 85/299
# ----------
# train Loss: 0.5880 Accuracy: 0.9946
# valid Loss: 51.5696 Accuracy: 0.9182
# Epoch 86/299
# ----------
# train Loss: 0.5164 Accuracy: 0.9950
# valid Loss: 50.7357 Accuracy: 0.9194
# Epoch 87/299
# ----------
# train Loss: 0.4285 Accuracy: 0.9961
# valid Loss: 49.8674 Accuracy: 0.9203
# Epoch 88/299
# ----------
# train Loss: 0.4103 Accuracy: 0.9962
# valid Loss: 51.6894 Accuracy: 0.9203
# Epoch 89/299
# ----------
# train Loss: 0.3965 Accuracy: 0.9962
# valid Loss: 52.3933 Accuracy: 0.9194
# Epoch 90/299
# ----------
# train Loss: 0.3737 Accuracy: 0.9966
# valid Loss: 52.7392 Accuracy: 0.9196
# Epoch 91/299
# ----------
# train Loss: 0.3750 Accuracy: 0.9966
# valid Loss: 52.5936 Accuracy: 0.9186
# Epoch 92/299
# ----------
# train Loss: 0.3752 Accuracy: 0.9971
# valid Loss: 53.0230 Accuracy: 0.9197
# Epoch 93/299
# ----------
# train Loss: 0.3733 Accuracy: 0.9964
# valid Loss: 55.1559 Accuracy: 0.9170
# Epoch 94/299
# ----------
# train Loss: 0.3421 Accuracy: 0.9974
# valid Loss: 52.3821 Accuracy: 0.9183
# Epoch 95/299
# ----------
# train Loss: 0.3150 Accuracy: 0.9971
# valid Loss: 52.4993 Accuracy: 0.9195
# Epoch 96/299
# ----------
# train Loss: 0.3592 Accuracy: 0.9965
# valid Loss: 53.7345 Accuracy: 0.9185
# Epoch 97/299
# ----------
# train Loss: 0.2970 Accuracy: 0.9973
# valid Loss: 52.4462 Accuracy: 0.9191
# Epoch 98/299
# ----------
# train Loss: 0.2917 Accuracy: 0.9975
# valid Loss: 53.4077 Accuracy: 0.9203
# Epoch 99/299
# ----------
# train Loss: 0.2850 Accuracy: 0.9973
# valid Loss: 55.6996 Accuracy: 0.9197
# Epoch 100/299
# ----------
# train Loss: 0.2667 Accuracy: 0.9980
# valid Loss: 52.2264 Accuracy: 0.9227
# Epoch 101/299
# ----------
# train Loss: 0.3072 Accuracy: 0.9972
# valid Loss: 54.7010 Accuracy: 0.9204
# Epoch 102/299
# ----------
# train Loss: 0.2675 Accuracy: 0.9977
# valid Loss: 55.4062 Accuracy: 0.9207
# Epoch 103/299
# ----------
# train Loss: 0.2829 Accuracy: 0.9975
# valid Loss: 54.3743 Accuracy: 0.9193
# Epoch 104/299
# ----------
# train Loss: 0.2817 Accuracy: 0.9973
# valid Loss: 54.3945 Accuracy: 0.9197
# Epoch 105/299
# ----------
# train Loss: 0.2833 Accuracy: 0.9974
# valid Loss: 55.1545 Accuracy: 0.9214
# Epoch 106/299
# ----------
# train Loss: 0.2515 Accuracy: 0.9977
# valid Loss: 53.5564 Accuracy: 0.9224
# Epoch 107/299
# ----------
# train Loss: 0.2658 Accuracy: 0.9975
# valid Loss: 54.0808 Accuracy: 0.9204
# Epoch 108/299
# ----------
# train Loss: 0.2240 Accuracy: 0.9982
# valid Loss: 56.7816 Accuracy: 0.9180
# Epoch 109/299
# ----------
# train Loss: 0.2880 Accuracy: 0.9971
# valid Loss: 57.3496 Accuracy: 0.9166
# Epoch 110/299
# ----------
# train Loss: 0.2549 Accuracy: 0.9980
# valid Loss: 55.1072 Accuracy: 0.9214
# Epoch 111/299
# ----------
# train Loss: 0.2274 Accuracy: 0.9982
# valid Loss: 55.7356 Accuracy: 0.9219
# Epoch 112/299
# ----------
# train Loss: 0.2314 Accuracy: 0.9980
# valid Loss: 54.8473 Accuracy: 0.9212
# Epoch 113/299
# ----------
# train Loss: 0.2217 Accuracy: 0.9982
# valid Loss: 56.5217 Accuracy: 0.9202
# Epoch 114/299
# ----------
# train Loss: 0.2442 Accuracy: 0.9977
# valid Loss: 55.7953 Accuracy: 0.9199
# Epoch 115/299
# ----------
# train Loss: 0.2495 Accuracy: 0.9978
# valid Loss: 55.8207 Accuracy: 0.9201
# Epoch 116/299
# ----------
# train Loss: 0.2104 Accuracy: 0.9982
# valid Loss: 56.1603 Accuracy: 0.9198
# Epoch 117/299
# ----------
# train Loss: 0.1999 Accuracy: 0.9984
# valid Loss: 56.8072 Accuracy: 0.9192
# Epoch 118/299
# ----------
# train Loss: 0.2030 Accuracy: 0.9983
# valid Loss: 57.2255 Accuracy: 0.9211
# Epoch 119/299
# ----------
# train Loss: 0.2081 Accuracy: 0.9983
# valid Loss: 54.2225 Accuracy: 0.9209
# Epoch 120/299
# ----------
# train Loss: 0.2210 Accuracy: 0.9979
# valid Loss: 56.2276 Accuracy: 0.9204
# Epoch 121/299
# ----------
# train Loss: 0.2065 Accuracy: 0.9983
# valid Loss: 56.9355 Accuracy: 0.9190
# Epoch 122/299
# ----------
# train Loss: 0.2168 Accuracy: 0.9980
# valid Loss: 56.4006 Accuracy: 0.9211
# Epoch 123/299
# ----------
# train Loss: 0.2223 Accuracy: 0.9980
# valid Loss: 55.5942 Accuracy: 0.9215
# Epoch 124/299
# ----------
# train Loss: 0.1663 Accuracy: 0.9985
# valid Loss: 55.8429 Accuracy: 0.9197
# Epoch 125/299
# ----------
# train Loss: 0.1608 Accuracy: 0.9987
# valid Loss: 54.3088 Accuracy: 0.9237
# Epoch 126/299
# ----------
# train Loss: 0.1527 Accuracy: 0.9988
# valid Loss: 54.8096 Accuracy: 0.9228
# Epoch 127/299
# ----------
# train Loss: 0.1439 Accuracy: 0.9989
# valid Loss: 56.0158 Accuracy: 0.9227
# Epoch 128/299
# ----------
# train Loss: 0.1388 Accuracy: 0.9988
# valid Loss: 55.7818 Accuracy: 0.9231
# Epoch 129/299
# ----------
# train Loss: 0.1252 Accuracy: 0.9992
# valid Loss: 56.8495 Accuracy: 0.9206
# Epoch 130/299
# ----------
# train Loss: 0.1196 Accuracy: 0.9991
# valid Loss: 54.6501 Accuracy: 0.9220
# Epoch 131/299
# ----------
# train Loss: 0.1217 Accuracy: 0.9992
# valid Loss: 54.6702 Accuracy: 0.9231
# Epoch 132/299
# ----------
# train Loss: 0.1150 Accuracy: 0.9992
# valid Loss: 54.6297 Accuracy: 0.9245
# Epoch 133/299
# ----------
# train Loss: 0.1045 Accuracy: 0.9994
# valid Loss: 54.7210 Accuracy: 0.9231
# Epoch 134/299
# ----------
# train Loss: 0.1205 Accuracy: 0.9990
# valid Loss: 54.8730 Accuracy: 0.9241
# Epoch 135/299
# ----------
# train Loss: 0.1081 Accuracy: 0.9994
# valid Loss: 54.4691 Accuracy: 0.9253
# Epoch 136/299
# ----------
# train Loss: 0.1163 Accuracy: 0.9991
# valid Loss: 55.4324 Accuracy: 0.9234
# Epoch 137/299
# ----------
# train Loss: 0.1146 Accuracy: 0.9992
# valid Loss: 55.4933 Accuracy: 0.9224
# Epoch 138/299
# ----------
# train Loss: 0.1294 Accuracy: 0.9990
# valid Loss: 54.5604 Accuracy: 0.9223
# Epoch 139/299
# ----------
# train Loss: 0.1071 Accuracy: 0.9992
# valid Loss: 54.4175 Accuracy: 0.9236
# Epoch 140/299
# ----------
# train Loss: 0.1086 Accuracy: 0.9992
# valid Loss: 54.1499 Accuracy: 0.9231
# Epoch 141/299
# ----------
# train Loss: 0.0923 Accuracy: 0.9994
# valid Loss: 54.3559 Accuracy: 0.9241
# Epoch 142/299
# ----------
# train Loss: 0.1084 Accuracy: 0.9992
# valid Loss: 54.1224 Accuracy: 0.9226
# Epoch 143/299
# ----------
# train Loss: 0.0947 Accuracy: 0.9993
# valid Loss: 53.7263 Accuracy: 0.9235
# Epoch 144/299
# ----------
# train Loss: 0.0926 Accuracy: 0.9993
# valid Loss: 53.3374 Accuracy: 0.9245
# Epoch 145/299
# ----------
# train Loss: 0.0933 Accuracy: 0.9994
# valid Loss: 53.8929 Accuracy: 0.9249
# Epoch 146/299
# ----------
# train Loss: 0.0927 Accuracy: 0.9994
# valid Loss: 54.4906 Accuracy: 0.9230
# Epoch 147/299
# ----------
# train Loss: 0.0762 Accuracy: 0.9996
# valid Loss: 54.0445 Accuracy: 0.9246
# Epoch 148/299
# ----------
# train Loss: 0.0876 Accuracy: 0.9994
# valid Loss: 54.8912 Accuracy: 0.9236
# Epoch 149/299
# ----------
# train Loss: 0.0842 Accuracy: 0.9995
# valid Loss: 54.7370 Accuracy: 0.9246
# Epoch 150/299
# ----------
# train Loss: 0.0911 Accuracy: 0.9994
# valid Loss: 54.8580 Accuracy: 0.9231
# Epoch 151/299
# ----------
# train Loss: 0.1044 Accuracy: 0.9992
# valid Loss: 54.5717 Accuracy: 0.9240
# Epoch 152/299
# ----------
# train Loss: 0.1022 Accuracy: 0.9993
# valid Loss: 54.8346 Accuracy: 0.9242
# Epoch 153/299
# ----------
# train Loss: 0.0807 Accuracy: 0.9994
# valid Loss: 54.1816 Accuracy: 0.9249
# Epoch 154/299
# ----------
# train Loss: 0.0864 Accuracy: 0.9994
# valid Loss: 54.8955 Accuracy: 0.9231
# Epoch 155/299
# ----------
# train Loss: 0.0830 Accuracy: 0.9995
# valid Loss: 54.3651 Accuracy: 0.9247
# Epoch 156/299
# ----------
# train Loss: 0.0711 Accuracy: 0.9997
# valid Loss: 54.0038 Accuracy: 0.9250
# Epoch 157/299
# ----------
# train Loss: 0.0829 Accuracy: 0.9995
# valid Loss: 54.4936 Accuracy: 0.9259
# Epoch 158/299
# ----------
# train Loss: 0.0808 Accuracy: 0.9994
# valid Loss: 53.6997 Accuracy: 0.9257
# Epoch 159/299
# ----------
# train Loss: 0.0857 Accuracy: 0.9994
# valid Loss: 54.6180 Accuracy: 0.9245
# Epoch 160/299
# ----------
# train Loss: 0.0738 Accuracy: 0.9995
# valid Loss: 54.2670 Accuracy: 0.9246
# Epoch 161/299
# ----------
# train Loss: 0.0832 Accuracy: 0.9994
# valid Loss: 54.3944 Accuracy: 0.9251
# Epoch 162/299
# ----------
# train Loss: 0.0879 Accuracy: 0.9995
# valid Loss: 54.3195 Accuracy: 0.9231
# Epoch 163/299
# ----------
# train Loss: 0.0765 Accuracy: 0.9996
# valid Loss: 54.3404 Accuracy: 0.9232
# Epoch 164/299
# ----------
# train Loss: 0.0808 Accuracy: 0.9993
# valid Loss: 54.1039 Accuracy: 0.9237
# Epoch 165/299
# ----------
# train Loss: 0.0775 Accuracy: 0.9996
# valid Loss: 54.1258 Accuracy: 0.9245
# Epoch 166/299
# ----------
# train Loss: 0.0790 Accuracy: 0.9995
# valid Loss: 55.0162 Accuracy: 0.9232
# Epoch 167/299
# ----------
# train Loss: 0.0729 Accuracy: 0.9996
# valid Loss: 54.2436 Accuracy: 0.9244
# Epoch 168/299
# ----------
# train Loss: 0.0674 Accuracy: 0.9995
# valid Loss: 53.8459 Accuracy: 0.9235
# Epoch 169/299
# ----------
# train Loss: 0.0885 Accuracy: 0.9993
# valid Loss: 54.6827 Accuracy: 0.9240
# Epoch 170/299
# ----------
# train Loss: 0.0784 Accuracy: 0.9994
# valid Loss: 54.0957 Accuracy: 0.9253
# Epoch 171/299
# ----------
# train Loss: 0.0634 Accuracy: 0.9997
# valid Loss: 54.4270 Accuracy: 0.9239
# Epoch 172/299
# ----------
# train Loss: 0.0788 Accuracy: 0.9995
# valid Loss: 54.3625 Accuracy: 0.9240
# Epoch 173/299
# ----------
# train Loss: 0.0690 Accuracy: 0.9997
# valid Loss: 55.0670 Accuracy: 0.9239
# Epoch 174/299
# ----------
# train Loss: 0.0779 Accuracy: 0.9996
# valid Loss: 54.5954 Accuracy: 0.9243
# Epoch 175/299
# ----------
# train Loss: 0.0762 Accuracy: 0.9994
# valid Loss: 54.1388 Accuracy: 0.9254
# Epoch 176/299
# ----------
# train Loss: 0.0830 Accuracy: 0.9995
# valid Loss: 54.7512 Accuracy: 0.9251
# Epoch 177/299
# ----------
# train Loss: 0.0760 Accuracy: 0.9995
# valid Loss: 54.0031 Accuracy: 0.9246
# Epoch 178/299
# ----------
# train Loss: 0.0656 Accuracy: 0.9997
# valid Loss: 53.7563 Accuracy: 0.9260
# Epoch 179/299
# ----------
# train Loss: 0.0844 Accuracy: 0.9993
# valid Loss: 54.7674 Accuracy: 0.9229
# Epoch 180/299
# ----------
# train Loss: 0.0871 Accuracy: 0.9993
# valid Loss: 54.9206 Accuracy: 0.9256
# Epoch 181/299
# ----------
# train Loss: 0.0814 Accuracy: 0.9994
# valid Loss: 54.2052 Accuracy: 0.9239
# Epoch 182/299
# ----------
# train Loss: 0.0710 Accuracy: 0.9996
# valid Loss: 54.8574 Accuracy: 0.9245
# Epoch 183/299
# ----------
# train Loss: 0.0719 Accuracy: 0.9996
# valid Loss: 54.4723 Accuracy: 0.9236
# Epoch 184/299
# ----------
# train Loss: 0.0687 Accuracy: 0.9996
# valid Loss: 54.2702 Accuracy: 0.9239
# Epoch 185/299
# ----------
# train Loss: 0.0813 Accuracy: 0.9994
# valid Loss: 54.6953 Accuracy: 0.9243
# Epoch 186/299
# ----------
# train Loss: 0.0725 Accuracy: 0.9996
# valid Loss: 54.6061 Accuracy: 0.9249
# Epoch 187/299
# ----------
# train Loss: 0.0765 Accuracy: 0.9995
# valid Loss: 54.5682 Accuracy: 0.9233
# Epoch 188/299
# ----------
# train Loss: 0.0799 Accuracy: 0.9995
# valid Loss: 54.3875 Accuracy: 0.9245
# Epoch 189/299
# ----------
# train Loss: 0.0881 Accuracy: 0.9994
# valid Loss: 54.2419 Accuracy: 0.9241
# Epoch 190/299
# ----------
# train Loss: 0.0750 Accuracy: 0.9996
# valid Loss: 54.3139 Accuracy: 0.9246
# Epoch 191/299
# ----------
# train Loss: 0.0742 Accuracy: 0.9996
# valid Loss: 54.4586 Accuracy: 0.9236
# Epoch 192/299
# ----------
# train Loss: 0.0726 Accuracy: 0.9995
# valid Loss: 54.3310 Accuracy: 0.9234
# Epoch 193/299
# ----------
# train Loss: 0.0736 Accuracy: 0.9996
# valid Loss: 53.9416 Accuracy: 0.9246
# Epoch 194/299
# ----------
# train Loss: 0.0689 Accuracy: 0.9996
# valid Loss: 53.7804 Accuracy: 0.9244
# Epoch 195/299
# ----------
# train Loss: 0.0658 Accuracy: 0.9997
# valid Loss: 54.6345 Accuracy: 0.9235
# Epoch 196/299
# ----------
# train Loss: 0.0792 Accuracy: 0.9994
# valid Loss: 53.9771 Accuracy: 0.9246
# Epoch 197/299
# ----------
# train Loss: 0.0753 Accuracy: 0.9996
# valid Loss: 54.2969 Accuracy: 0.9248
# Epoch 198/299
# ----------
# train Loss: 0.0872 Accuracy: 0.9994
# valid Loss: 54.5005 Accuracy: 0.9249
# Epoch 199/299
# ----------
# train Loss: 0.0756 Accuracy: 0.9995
# valid Loss: 54.0306 Accuracy: 0.9238
# Epoch 200/299
# ----------
# train Loss: 0.0684 Accuracy: 0.9995
# valid Loss: 54.3698 Accuracy: 0.9233
# Epoch 201/299
# ----------
# train Loss: 0.0790 Accuracy: 0.9995
# valid Loss: 54.6618 Accuracy: 0.9242
# Epoch 202/299
# ----------
# train Loss: 0.0684 Accuracy: 0.9996
# valid Loss: 54.2411 Accuracy: 0.9251
# Epoch 203/299
# ----------
# train Loss: 0.0585 Accuracy: 0.9998
# valid Loss: 54.1588 Accuracy: 0.9243
# Epoch 204/299
# ----------
# train Loss: 0.0695 Accuracy: 0.9997
# valid Loss: 54.3685 Accuracy: 0.9247
# Epoch 205/299
# ----------
# train Loss: 0.0692 Accuracy: 0.9997
# valid Loss: 54.3922 Accuracy: 0.9240
# Epoch 206/299
# ----------
# train Loss: 0.0726 Accuracy: 0.9996
# valid Loss: 53.8236 Accuracy: 0.9241
# Epoch 207/299
# ----------
# train Loss: 0.0637 Accuracy: 0.9997
# valid Loss: 54.3555 Accuracy: 0.9249
# Epoch 208/299
# ----------
# train Loss: 0.0749 Accuracy: 0.9995
# valid Loss: 54.2881 Accuracy: 0.9245
# Epoch 209/299
# ----------
# train Loss: 0.0679 Accuracy: 0.9996
# valid Loss: 54.7078 Accuracy: 0.9244
# Epoch 210/299
# ----------
# train Loss: 0.0679 Accuracy: 0.9996
# valid Loss: 54.1878 Accuracy: 0.9254
# Epoch 211/299
# ----------
# train Loss: 0.0826 Accuracy: 0.9995
# valid Loss: 54.6659 Accuracy: 0.9240
# Epoch 212/299
# ----------
# train Loss: 0.0779 Accuracy: 0.9995
# valid Loss: 54.6003 Accuracy: 0.9248
# Epoch 213/299
# ----------
# train Loss: 0.0770 Accuracy: 0.9993
# valid Loss: 53.8497 Accuracy: 0.9239
# Epoch 214/299
# ----------
# train Loss: 0.0724 Accuracy: 0.9996
# valid Loss: 55.1480 Accuracy: 0.9239
# Epoch 215/299
# ----------
# train Loss: 0.0687 Accuracy: 0.9995
# valid Loss: 54.3532 Accuracy: 0.9250
# Epoch 216/299
# ----------
# train Loss: 0.0665 Accuracy: 0.9996
# valid Loss: 54.4420 Accuracy: 0.9246
# Epoch 217/299
# ----------
# train Loss: 0.0693 Accuracy: 0.9996
# valid Loss: 54.3242 Accuracy: 0.9244
# Epoch 218/299
# ----------
# train Loss: 0.0694 Accuracy: 0.9995
# valid Loss: 54.0602 Accuracy: 0.9244
# Epoch 219/299
# ----------
# train Loss: 0.0715 Accuracy: 0.9996
# valid Loss: 54.6691 Accuracy: 0.9237
# Epoch 220/299
# ----------
# train Loss: 0.0640 Accuracy: 0.9997
# valid Loss: 54.9441 Accuracy: 0.9238
# Epoch 221/299
# ----------
# train Loss: 0.0662 Accuracy: 0.9996
# valid Loss: 54.4927 Accuracy: 0.9238
# Epoch 222/299
# ----------
# train Loss: 0.0617 Accuracy: 0.9997
# valid Loss: 54.5925 Accuracy: 0.9253
# Epoch 223/299
# ----------
# train Loss: 0.0704 Accuracy: 0.9996
# valid Loss: 55.1642 Accuracy: 0.9245
# Epoch 224/299
# ----------
# train Loss: 0.0697 Accuracy: 0.9995
# valid Loss: 54.4560 Accuracy: 0.9241
# Epoch 225/299
# ----------
# train Loss: 0.0668 Accuracy: 0.9997
# valid Loss: 54.5154 Accuracy: 0.9241
# Epoch 226/299
# ----------
# train Loss: 0.0729 Accuracy: 0.9995
# valid Loss: 54.3723 Accuracy: 0.9228
# Epoch 227/299
# ----------
# train Loss: 0.0742 Accuracy: 0.9995
# valid Loss: 54.3952 Accuracy: 0.9246
# Epoch 228/299
# ----------
# train Loss: 0.0732 Accuracy: 0.9994
# valid Loss: 53.9547 Accuracy: 0.9247
# Epoch 229/299
# ----------
# train Loss: 0.0774 Accuracy: 0.9995
# valid Loss: 54.6335 Accuracy: 0.9243
# Epoch 230/299
# ----------
# train Loss: 0.0679 Accuracy: 0.9995
# valid Loss: 54.9393 Accuracy: 0.9237
# Epoch 231/299
# ----------
# train Loss: 0.0664 Accuracy: 0.9996
# valid Loss: 53.9798 Accuracy: 0.9246
# Epoch 232/299
# ----------
# train Loss: 0.0752 Accuracy: 0.9994
# valid Loss: 54.3301 Accuracy: 0.9251
# Epoch 233/299
# ----------
# train Loss: 0.0621 Accuracy: 0.9997
# valid Loss: 54.0648 Accuracy: 0.9243
# Epoch 234/299
# ----------
# train Loss: 0.0708 Accuracy: 0.9997
# valid Loss: 54.5399 Accuracy: 0.9242
# Epoch 235/299
# ----------
# train Loss: 0.0741 Accuracy: 0.9996
# valid Loss: 54.7498 Accuracy: 0.9240
# Epoch 236/299
# ----------
# train Loss: 0.0800 Accuracy: 0.9995
# valid Loss: 53.9322 Accuracy: 0.9252
# Epoch 237/299
# ----------
# train Loss: 0.0812 Accuracy: 0.9994
# valid Loss: 54.4608 Accuracy: 0.9244
# Epoch 238/299
# ----------
# train Loss: 0.0728 Accuracy: 0.9996
# valid Loss: 54.2956 Accuracy: 0.9251
# Epoch 239/299
# ----------
# train Loss: 0.0666 Accuracy: 0.9997
# valid Loss: 54.0586 Accuracy: 0.9246
# Epoch 240/299
# ----------
# train Loss: 0.0739 Accuracy: 0.9995
# valid Loss: 54.1619 Accuracy: 0.9235
# Epoch 241/299
# ----------
# train Loss: 0.0632 Accuracy: 0.9996
# valid Loss: 54.7534 Accuracy: 0.9249
# Epoch 242/299
# ----------
# train Loss: 0.0717 Accuracy: 0.9996
# valid Loss: 54.4813 Accuracy: 0.9246
# Epoch 243/299
# ----------
# train Loss: 0.0692 Accuracy: 0.9996
# valid Loss: 54.2547 Accuracy: 0.9248
# Epoch 244/299
# ----------
# train Loss: 0.0787 Accuracy: 0.9995
# valid Loss: 53.7445 Accuracy: 0.9246
# Epoch 245/299
# ----------
# train Loss: 0.0814 Accuracy: 0.9995
# valid Loss: 54.4941 Accuracy: 0.9250
# Epoch 246/299
# ----------
# train Loss: 0.0775 Accuracy: 0.9995
# valid Loss: 55.1164 Accuracy: 0.9249
# Epoch 247/299
# ----------
# train Loss: 0.0709 Accuracy: 0.9995
# valid Loss: 54.8475 Accuracy: 0.9244
# Epoch 248/299
# ----------
# train Loss: 0.0641 Accuracy: 0.9997
# valid Loss: 55.4977 Accuracy: 0.9249
# Epoch 249/299
# ----------
# train Loss: 0.0740 Accuracy: 0.9995
# valid Loss: 54.1056 Accuracy: 0.9241
# Epoch 250/299
# ----------
# train Loss: 0.0718 Accuracy: 0.9996
# valid Loss: 54.0066 Accuracy: 0.9246
# Epoch 251/299
# ----------
# train Loss: 0.0656 Accuracy: 0.9997
# valid Loss: 54.1269 Accuracy: 0.9244
# Epoch 252/299
# ----------
# train Loss: 0.0803 Accuracy: 0.9993
# valid Loss: 54.7847 Accuracy: 0.9254
# Epoch 253/299
# ----------
# train Loss: 0.0581 Accuracy: 0.9998
# valid Loss: 55.2388 Accuracy: 0.9243
# Epoch 254/299
# ----------
# train Loss: 0.0772 Accuracy: 0.9995
# valid Loss: 53.6875 Accuracy: 0.9247
# Epoch 255/299
# ----------
# train Loss: 0.0800 Accuracy: 0.9996
# valid Loss: 55.0764 Accuracy: 0.9248
# Epoch 256/299
# ----------
# train Loss: 0.0611 Accuracy: 0.9997
# valid Loss: 54.8837 Accuracy: 0.9242
# Epoch 257/299
# ----------
# train Loss: 0.0691 Accuracy: 0.9995
# valid Loss: 54.5841 Accuracy: 0.9253
# Epoch 258/299
# ----------
# train Loss: 0.0676 Accuracy: 0.9996
# valid Loss: 53.9450 Accuracy: 0.9245
# Epoch 259/299
# ----------
# train Loss: 0.0620 Accuracy: 0.9996
# valid Loss: 54.5046 Accuracy: 0.9236
# Epoch 260/299
# ----------
# train Loss: 0.0661 Accuracy: 0.9996
# valid Loss: 53.9013 Accuracy: 0.9241
# Epoch 261/299
# ----------
# train Loss: 0.0627 Accuracy: 0.9997
# valid Loss: 54.3324 Accuracy: 0.9240
# Epoch 262/299
# ----------
# train Loss: 0.0666 Accuracy: 0.9995
# valid Loss: 54.3911 Accuracy: 0.9245
# Epoch 263/299
# ----------
# train Loss: 0.0728 Accuracy: 0.9995
# valid Loss: 55.3928 Accuracy: 0.9239
# Epoch 264/299
# ----------
# train Loss: 0.0760 Accuracy: 0.9995
# valid Loss: 54.3147 Accuracy: 0.9237
# Epoch 265/299
# ----------
# train Loss: 0.0695 Accuracy: 0.9995
# valid Loss: 54.0819 Accuracy: 0.9248
# Epoch 266/299
# ----------
# train Loss: 0.0744 Accuracy: 0.9996
# valid Loss: 54.8143 Accuracy: 0.9241
# Epoch 267/299
# ----------
# train Loss: 0.0673 Accuracy: 0.9995
# valid Loss: 54.5959 Accuracy: 0.9247
# Epoch 268/299
# ----------
# train Loss: 0.0666 Accuracy: 0.9997
# valid Loss: 54.7637 Accuracy: 0.9237
# Epoch 269/299
# ----------
# train Loss: 0.0630 Accuracy: 0.9997
# valid Loss: 54.2819 Accuracy: 0.9240
# Epoch 270/299
# ----------
# train Loss: 0.0712 Accuracy: 0.9996
# valid Loss: 54.3097 Accuracy: 0.9248
# Epoch 271/299
# ----------
# train Loss: 0.0662 Accuracy: 0.9996
# valid Loss: 54.7166 Accuracy: 0.9239
# Epoch 272/299
# ----------
# train Loss: 0.0672 Accuracy: 0.9996
# valid Loss: 54.5488 Accuracy: 0.9241
# Epoch 273/299
# ----------
# train Loss: 0.0727 Accuracy: 0.9996
# valid Loss: 54.0691 Accuracy: 0.9242
# Epoch 274/299
# ----------
# train Loss: 0.0748 Accuracy: 0.9995
# valid Loss: 54.7014 Accuracy: 0.9234
# Epoch 275/299
# ----------
# train Loss: 0.0686 Accuracy: 0.9996
# valid Loss: 54.3596 Accuracy: 0.9251
# Epoch 276/299
# ----------
# train Loss: 0.0703 Accuracy: 0.9995
# valid Loss: 55.2252 Accuracy: 0.9236
# Epoch 277/299
# ----------
# train Loss: 0.0713 Accuracy: 0.9996
# valid Loss: 54.6948 Accuracy: 0.9255
# Epoch 278/299
# ----------
# train Loss: 0.0744 Accuracy: 0.9995
# valid Loss: 54.5006 Accuracy: 0.9241
# Epoch 279/299
# ----------
# train Loss: 0.0610 Accuracy: 0.9997
# valid Loss: 53.6018 Accuracy: 0.9237
# Epoch 280/299
# ----------
# train Loss: 0.0647 Accuracy: 0.9997
# valid Loss: 54.6471 Accuracy: 0.9244
# Epoch 281/299
# ----------
# train Loss: 0.0659 Accuracy: 0.9997
# valid Loss: 54.7725 Accuracy: 0.9247
# Epoch 282/299
# ----------
# train Loss: 0.0666 Accuracy: 0.9997
# valid Loss: 54.6597 Accuracy: 0.9246
# Epoch 283/299
# ----------
# train Loss: 0.0744 Accuracy: 0.9996
# valid Loss: 54.1589 Accuracy: 0.9241
# Epoch 284/299
# ----------
# train Loss: 0.0773 Accuracy: 0.9994
# valid Loss: 54.7235 Accuracy: 0.9242
# Epoch 285/299
# ----------
# train Loss: 0.0646 Accuracy: 0.9996
# valid Loss: 54.4002 Accuracy: 0.9244
# Epoch 286/299
# ----------
# train Loss: 0.0754 Accuracy: 0.9995
# valid Loss: 54.9222 Accuracy: 0.9247
# Epoch 287/299
# ----------
# train Loss: 0.0672 Accuracy: 0.9997
# valid Loss: 54.2910 Accuracy: 0.9245
# Epoch 288/299
# ----------
# train Loss: 0.0791 Accuracy: 0.9993
# valid Loss: 54.2117 Accuracy: 0.9241
# Epoch 289/299
# ----------
# train Loss: 0.0889 Accuracy: 0.9994
# valid Loss: 54.5810 Accuracy: 0.9236
# Epoch 290/299
# ----------
# train Loss: 0.0782 Accuracy: 0.9994
# valid Loss: 54.2658 Accuracy: 0.9251
# Epoch 291/299
# ----------
# train Loss: 0.0604 Accuracy: 0.9997
# valid Loss: 54.4435 Accuracy: 0.9238
# Epoch 292/299
# ----------
# train Loss: 0.0755 Accuracy: 0.9996
# valid Loss: 54.4839 Accuracy: 0.9244
# Epoch 293/299
# ----------
# train Loss: 0.0698 Accuracy: 0.9996
# valid Loss: 54.4645 Accuracy: 0.9237
# Epoch 294/299
# ----------
# train Loss: 0.0769 Accuracy: 0.9996
# valid Loss: 54.6137 Accuracy: 0.9248
# Epoch 295/299
# ----------
# train Loss: 0.0631 Accuracy: 0.9998
# valid Loss: 54.7582 Accuracy: 0.9237
# Epoch 296/299
# ----------
# train Loss: 0.0710 Accuracy: 0.9996
# valid Loss: 54.0269 Accuracy: 0.9237
# Epoch 297/299
# ----------
# train Loss: 0.0730 Accuracy: 0.9995
# valid Loss: 54.3169 Accuracy: 0.9250
# Epoch 298/299
# ----------
# train Loss: 0.0595 Accuracy: 0.9997
# valid Loss: 54.7312 Accuracy: 0.9245
# Epoch 299/299
# ----------
# train Loss: 0.0673 Accuracy: 0.9997
# valid Loss: 54.8060 Accuracy: 0.9245
# Training complete in 108m 19s
# Best val Accuracy: 0.926000

# %%
# Image show for Tensor
def imshow(inp, title = None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# Visualizing the images with its respective label
def visualize_model(model, num_images = 6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {classes[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)
        
visualize_model(model)

# %% [markdown]
# # Testing the model

# %%
def test_model(model):
    
    was_training = model.training
    model.eval()
    all_labels = []
    all_preds = []


    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_labels.append(labels)
            all_preds.append(preds)
            
    model.train(mode=was_training)
    return all_labels, all_preds
    
labels, preds = test_model(model)

# %%
# Actual labels & Predictive labels
labels = [j  for i in labels for j in i.cpu().tolist()[:]]
preds = [j  for i in preds for j in i.cpu().tolist()[:]]

# %% [markdown]
# # Performance Metrics

# %%
# Printing overall metrics
print("Overall metrics")
print("Accuracy:", accuracy_score(labels, preds))
print("Recall:", recall_score(labels, preds, average='weighted'))
print("Precision:", precision_score(labels, preds, average='weighted'))
print("F1:", f1_score(labels, preds, average='weighted'))
# Out:
# Overall metrics
# Accuracy: 0.9266
# Recall: 0.9266
# Precision: 0.92650090841321
# F1: 0.9265005358781738

# %%
# Printing indiviual metrics, recall, precision and f1 scores for each classes separately
recall_scores = recall_score(labels, preds, average=None)
precision_scores = precision_score(labels, preds, average=None)
f1_scores = f1_score(labels, preds, average=None)
scores = pd.DataFrame({'Class': classes, 'Recall': recall_scores, 'Precision':precision_scores,'F1':f1_scores})
print(scores)
# Out:
#    Class  Recall  Precision        F1
# 0  plane   0.934   0.926587  0.930279
# 1    car   0.971   0.960435  0.965689
# 2   bird   0.900   0.910010  0.904977
# 3    cat   0.838   0.863028  0.850330
# 4   deer   0.927   0.917822  0.922388
# 5    dog   0.899   0.881373  0.890099
# 6   frog   0.942   0.952477  0.947210
# 7  horse   0.945   0.947844  0.946420
# 8   ship   0.962   0.945919  0.953892
# 9  truck   0.948   0.959514  0.953722

# %% [markdown]
# # Inference

# %%
# Plotting the accuracy for Training and Validation
def plot_accuracies(training_accuracy, validation_accuracy):
    plt.figure(figsize = (5, 5))
    plt.plot(training_accuracy, '-x')
    plt.plot(validation_accuracy, '-x')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Accuracy vs. Epochs');

# %%
plot_accuracies([i.cpu() for i in training_accuracy], [i.cpu() for i in validation_accuracy])

# %%
# Plotting the Loss for Training and Validation
def plot_losses(training_loss, validation_loss):
    plt.figure(figsize = (5, 5))
    plt.plot(training_loss, '-x')
    plt.plot(validation_loss, '-x')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. Epochs');

# %%
plot_losses(training_loss, validation_loss )

# %% [markdown]
# # References

# %% [markdown]
# 1) https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
# 2) https://github.com/kuangliu/pytorch-cifar
# 3) He, K.; Zhang, X.; Ren, S.; and Sun, J. 2016. Deep Residual Learning for Image Recognition. In Proceedings of 2016IEEE  Conference on Computer Vision and Pattern Recognition, CVPR ’16, 770–778. IEEE.
